# %%
import pandas as pd
data = pd.read_excel('Yachin.xlsx',skiprows=11, header=None, usecols= "F:V")
data.head(10)
# Out:
#           5   6                    7         8       9        10       11  \
# 0   00000_全国   1                00_総数  18976200  377600  2263700  3303600
# 1   00000_全国   1             10_公営の借家   1921700   21500  1207100   560200
# 2   00000_全国   1  20_都市再生機構(UR)・公社の借家    747200     300     9500   181100
# 3   00000_全国   1              30_民営借家  15225400  257000   640500  2324500
# 4   00000_全国   1              40_給与住宅   1082000   98800   406600   237700
# 5  01000_北海道   1                00_総数    992700   21100   219000   246700
# 6  01000_北海道   1             10_公営の借家    155500    1900   125400    24300
# 7  01000_北海道   1  20_都市再生機構(UR)・公社の借家      6300       -      200     4200
# 8  01000_北海道   1              30_民営借家    766700   12200    53700   208700
# 9  01000_北海道   1              40_給与住宅     64200    7000    39700     9500
#
#         12       13       14       15       16      17     18      19    20  \
# 0  4787800  2950000  1797700  1102300  1097700  451300  68600  776000  1196
# ...

# %%
len(data)
# Out:
# 6550

# %%
col_data = pd.read_excel('Yachin.xlsx',skiprows=5, header=None, usecols= "F:V")
col_data = col_data.head(6)
col_data = col_data.drop(([2,4]), axis=0)
col_data
# Out:
#                   5   6         7             8             9             10  \
# 0                NaN NaN       NaN     借家（専用住宅）数     借家（専用住宅）数     借家（専用住宅）数
# 1                NaN NaN       NaN  延べ面積１ｍ2当たり家賃  延べ面積１ｍ2当たり家賃  延べ面積１ｍ2当たり家賃
# 3                NaN NaN       NaN         00_総数         01_0円   02_1～500円未満
# 5  地域区分－全国・都道府県・市区町村 NaN  住宅の所有の関係                         NaN           NaN
#
#                 11                 12                 13                 14  \
# 0        借家（専用住宅）数          借家（専用住宅）数          借家（専用住宅）数          借家（専用住宅）数
# 1     延べ面積１ｍ2当たり家賃       延べ面積１ｍ2当たり家賃       延べ面積１ｍ2当たり家賃       延べ面積１ｍ2当たり家賃
# 3  03_500～1,000円未満  04_1,000～1,500円未満  05_1,500～2,000円未満  06_2,000～2,500円未満
# 5              NaN                NaN                NaN                NaN
#
#                   15                 16                 17            18  \
# 0          借家（専用住宅）数          借家（専用住宅）数          借家（専用住宅）数     借家（専用住宅）数
# ...

# %%
cols =[]
for i in col_data.columns:
    tg_col = '_'.join(list(col_data[i].dropna()))
    cols.append(tg_col)
cols
# Out:
# ['地域区分－全国・都道府県・市区町村',
#  '',
#  '住宅の所有の関係',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_00_総数_ ',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_01_0円',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_02_1～500円未満',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_03_500～1,000円未満',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_04_1,000～1,500円未満',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_05_1,500～2,000円未満',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_06_2,000～2,500円未満',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_07_2,500～3,000円未満',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_08_3,000～4,000円未満',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_09_4,000～6,000円未満',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_10_6,000円以上',
#  '借家（専用住宅）数_延べ面積１ｍ2当たり家賃_99_不詳',
#  '延べ面積１ｍ2当たり家賃_住宅の家賃の平均_1_家賃０円を含む',
#  '延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない']

# %%
data.columns = cols
data.head()
# Out:
#   地域区分－全国・都道府県・市区町村                住宅の所有の関係 借家（専用住宅）数_延べ面積１ｍ2当たり家賃_00_総数_   \
# 0          00000_全国  1                00_総数                       18976200
# 1          00000_全国  1             10_公営の借家                        1921700
# 2          00000_全国  1  20_都市再生機構(UR)・公社の借家                         747200
# 3          00000_全国  1              30_民営借家                       15225400
# 4          00000_全国  1              40_給与住宅                        1082000
#
#   借家（専用住宅）数_延べ面積１ｍ2当たり家賃_01_0円 借家（専用住宅）数_延べ面積１ｍ2当たり家賃_02_1～500円未満  \
# 0                       377600                            2263700
# 1                        21500                            1207100
# 2                          300                               9500
# 3                       257000                             640500
# 4                        98800                             406600
#
#   借家（専用住宅）数_延べ面積１ｍ2当たり家賃_03_500～1,000円未満  \
# 0                                3303600
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_sousuu = data.query("住宅の所有の関係.str.startswith('00_総数')",engine='python')
data_sousuu
# Out:
#      地域区分－全国・都道府県・市区町村    住宅の所有の関係 借家（専用住宅）数_延べ面積１ｍ2当たり家賃_00_総数_   \
# 0             00000_全国  1    00_総数                       18976200
# 5            01000_北海道  1    00_総数                         992700
# 10           01100_札幌市  1    00_総数                         444200
# 15       01101_札幌市　中央区  1    00_総数                          73280
# 20        01102_札幌市　北区  1    00_総数                          61510
# ...                ... ..      ...                            ...
# 6525         47328_中城村  1    00_総数                           3650
# 6530         47329_西原町  1    00_総数                           6110
# 6535        47348_与那原町  1    00_総数                           3520
# 6540        47350_南風原町  1    00_総数                           6270
# 6545        47362_八重瀬町  1    00_総数                           3090
#
#      借家（専用住宅）数_延べ面積１ｍ2当たり家賃_01_0円 借家（専用住宅）数_延べ面積１ｍ2当たり家賃_02_1～500円未満  \
# 0                          377600                            2263700
# ...

# %%
len(data_sousuu)
# Out:
# 1310

# %%
data_sousuu[['地域区分－全国・都道府県・市区町村','延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない']]
# Out:
#      地域区分－全国・都道府県・市区町村 延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない
# 0             00000_全国                              1235
# 5            01000_北海道                               837
# 10           01100_札幌市                              1064
# 15       01101_札幌市　中央区                              1277
# 20        01102_札幌市　北区                              1089
# ...                ...                               ...
# 6525         47328_中城村                              1196
# 6530         47329_西原町                              1038
# 6535        47348_与那原町                              1021
# 6540        47350_南風原町                              1110
# 6545        47362_八重瀬町                               980
#
# [1310 rows x 2 columns]

# %%
data_sousuu_2=data_sousuu[['地域区分－全国・都道府県・市区町村','延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない']].copy()
data_sousuu_2
# Out:
#      地域区分－全国・都道府県・市区町村 延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない
# 0             00000_全国                              1235
# 5            01000_北海道                               837
# 10           01100_札幌市                              1064
# 15       01101_札幌市　中央区                              1277
# 20        01102_札幌市　北区                              1089
# ...                ...                               ...
# 6525         47328_中城村                              1196
# 6530         47329_西原町                              1038
# 6535        47348_与那原町                              1021
# 6540        47350_南風原町                              1110
# 6545        47362_八重瀬町                               980
#
# [1310 rows x 2 columns]

# %%
data_sousuu_2[['コード','全国・都道府県・市区町村']] = data_sousuu_2['地域区分－全国・都道府県・市区町村'].str.split('_',expand=True)

# %%
data_sousuu_2
# Out:
#      地域区分－全国・都道府県・市区町村 延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない    コード 全国・都道府県・市区町村
# 0             00000_全国                              1235  00000           全国
# 5            01000_北海道                               837  01000          北海道
# 10           01100_札幌市                              1064  01100          札幌市
# 15       01101_札幌市　中央区                              1277  01101      札幌市　中央区
# 20        01102_札幌市　北区                              1089  01102       札幌市　北区
# ...                ...                               ...    ...          ...
# 6525         47328_中城村                              1196  47328          中城村
# 6530         47329_西原町                              1038  47329          西原町
# 6535        47348_与那原町                              1021  47348         与那原町
# 6540        47350_南風原町                              1110  47350         南風原町
# 6545        47362_八重瀬町                               980  47362         八重瀬町
#
# [1310 rows x 4 columns]

# %%
data_sousuu_2[['コード','延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない']]
# Out:
#         コード 延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない
# 0     00000                              1235
# 5     01000                               837
# 10    01100                              1064
# 15    01101                              1277
# 20    01102                              1089
# ...     ...                               ...
# 6525  47328                              1196
# 6530  47329                              1038
# 6535  47348                              1021
# 6540  47350                              1110
# 6545  47362                               980
#
# [1310 rows x 2 columns]

# %%
data_sousuu_2.dtypes
# Out:
# 地域区分－全国・都道府県・市区町村                    object
# 延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない    object
# コード                                  object
# 全国・都道府県・市区町村                         object
# dtype: object

# %%
data_code = data_sousuu_2[['コード','延べ面積１ｍ2当たり家賃_住宅の家賃の平均_2_家賃０円を含まない']].drop()
